# %% [markdown]
# best practices for ML,NLP
#
# 1. feature engineering - preprocessing and cleaning
# 2. Train Test Split
# 3. BOW or TF-IDF(sentences --> vectors) {preventing data leakage}
# 4. Trained our model
# 5. test model using test data not influenced by train data
